# %% [markdown]
# #**Chat with Multiple PDF's Llama 2 + Pinecone + LangChain**

# %% [markdown]
# #**Step: 01: Install All the Required Packages**

# %%
# !pip install langchain
# !pip install pinecone-client
# !pip install sentence_transformers
# !pip install pdf2image
# !pip install pypdf
# !pip install xformers
# !pip install bitsandbytes accelerate transformers

# %% [markdown]
# #**Step 2: Import All the Required Libraries**

# %%
from langchain.document_loaders import PyPDFDirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Pinecone
import pinecone
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers import pipeline
import os
import sys
import torch
# Out:
# c:\Users\benha\AppData\Local\Programs\Python\Python311\Lib\site-packages\pinecone\index.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
from langchain import HuggingFacePipeline, PromptTemplate
from langchain.chains import RetrievalQA

# %% [markdown]
# #**Step 3: Load the PDF Files**

# %%
# !mkdir pdfs
# Out:
# A subdirectory or file pdfs already exists.

# %% [markdown]
# #**Step 04: Extract the text from the PDF's**

# %%
loader = PyPDFDirectoryLoader("pdfs")
data = loader.load()

# %%
print(data)
# Out:
# [Document(page_content='Thermodynamics  ', metadata={'source': 'pdfs\\Chapter_1.pdf', 'page': 0}), Document(page_content='Information:  \nContact:  \n\uf0a7Email: maria.fahed@inervenants.efrei.fr  \n       Contact me trough email or @teams for any question.  \nNumber of classes:  \n \n \n \nEvaluation:  \n\uf0a7Midterm exam: 30%  \n\uf0a7Final exam: 50%  \n\uf0a7Tutorials: 20%  Modules  Tutorials  \n7 7 \nChapters:  \n•Fundamentals of Thermodynamics   \n•First Law of Thermodynamics    \n•Second  Law of Thermodynamics     \n•Thermal machines   ', metadata={'source': 'pdfs\\Chapter_1.pdf', 'page': 1}), Document(page_content='Fundamentals of Thermodynamics   Thermodynamics  \nClass nb 1  ', metadata={'source': 'pdfs\\Chapter_1.pdf', 'page': 2}), Document(page_content='Course outline  \nI.Introduction  \nII.States of matter  \nIII.Scales of study  \nIV.Thermodynamic system  \nV.Ideal and Van Der  Waals gases  \nVI.Thermoelastic  coefficients  ', metadata={'source': 'pdfs\\Chapter_1.pdf', 'page': 3}), Document(page_content='Thermodynamics  is a very important  branch  of both  physics  and \nchemistry . It deals  with the study  of energy,  the conversion  of energy  \nbetween  different  forms  and the ability  of energy  to do work . Why study thermodynamics?  Introduction  \nThermodynamics  \nPressure  Temperature  \nThermal conductivity  Thermal capacity  ', metadata={'source': 'pdfs\\Chapter_1.pdf', 'page': 4}), Document(page_content='Pressure  \n  \n At the top of a \nmountain  In an airplane in \nflight  \nIntroduction  \nHow to explain \nthe inflation of \nthe chips \npacket?  \n What the two \nsituations have \nin common ? the pressure can be \nseen as the action \nof the particles of a \ngas on the wall of \nthe container that \ncontains it. The \nsuccessive impacts \nof the particles act \nas a force on the \nwall.  \nThe pressure is in force per unit area:  \nP= F/A  \nF is the force in N  \nA area in m2  \nP is the pressure in N/  m2 or Pa  \nThe atmospheric pressure at low attitude ≈ 1 bar = 105  Pa ', metadata={'source': 'pdfs\\Chapter_1.pdf', 'page': 5}), Document(page_content='Temperature and Thermal conductivity  \n  \nWood  Metal  Introduction  \nThe temperature of the wood and \nthe metal is the same.  \nHow to explain the difference in \nsensation between the two types \nof materials??  \nThe temperature is a parameter that accounts for the thermal \nagitation, example: the stirring speed of the particles of a gas or \nthe speed of vibration in a solid.  \nA good thermal conductor material will allow to transmit these \nvibrations well.  ', metadata={'source': 'pdfs\\Chapter_1.pdf', 'page': 6}), Document(page_content='Thermal capacity  \n  Introduction  \n \n \nA pizza on a metal dish A pizza on aluminum foil  \nHow do you proceed to remove \nthe pizza from the oven at 230 ° C \nat the end of cooking?  \nThe ability to store energy in thermal form is called \nthermal capacity.  \nThis stored energy depends both on the temperature \nbut also on the system itself.  \nFor the same volume and the same temperature, a \ngas will store less energy than a metal for example.  ', metadata={'source': 'pdfs\\Chapter_1.pdf', 'page': 7}), Document(page_content='Introduction   \n \nPressure  Temperature  \nType of material  \nWhen two states of \nthe same pure body \ncoexist (example: \nwater/ice) there is a \nconstant \ntemperature as long \nas this situation exists.  The change of state \ntemperature of a pure \nbody depends on the \npressure.  \nThermal conductivity  \n& Thermal capacity   \nAll these parameters \nare linked together  ', metadata={'source': 'pdfs\\Chapter_1.pdf', 'page': 8}), Document(page_content='States of matter   \n \nSolid Phase  \n\uf0fcIdeal model: Perfect crystal  \n\uf0fcSmall inter -particle distances \nand strong interactions  \n\uf0fcQuasi -incompressible and a \nlittle expandable  Liquid Phase  \n\uf0fcParticles in contact but the \ninteractions are less strong: possible \nmovement  \n\uf0fcTa ...

# %% [markdown]
# #**Step 05: Split the Extracted Data into Text Chunks**

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=384, chunk_overlap=20)

# %%
docs = text_splitter.split_documents(data)

# %%
print(len(docs))
# Out:
# 276

# %%
docs[3]
# Out:
# Document(page_content='Fundamentals of Thermodynamics   Thermodynamics  \nClass nb 1', metadata={'source': 'pdfs\\Chapter_1.pdf', 'page': 2})

# %%
docs[4]
# Out:
# Document(page_content='Course outline  \nI.Introduction  \nII.States of matter  \nIII.Scales of study  \nIV.Thermodynamic system  \nV.Ideal and Van Der  Waals gases  \nVI.Thermoelastic  coefficients', metadata={'source': 'pdfs\\Chapter_1.pdf', 'page': 3})

# %% [markdown]
# #**Step 06: Downlaod the Embeddings From the Hugging Face**

# %%
embeddings = HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')

# %%
query_result = embeddings.embed_query("Hello World")

# %%
print("Length", len(query_result))
# Out:
# Length 384

# %% [markdown]
# #**Step 07: Initializing the Pinecone**

# %%
PINECONE_API_KEY = os.environ.get('PINECONE_API_KEY', 'e625eff7-7e12-48a1-aab4-2d53d3670ce7')
PINECONE_API_ENV = os.environ.get('PINECONE_API_ENV', 'gcp-starter')

# %%
# initialize pinecone
pinecone.init(
    api_key=PINECONE_API_KEY,  # find at app.pinecone.io
    environment=PINECONE_API_ENV  # next to api key in console
)
index_name = "chatbotpdfs" # put in the name of your pinecone index here

# %% [markdown]
# #**Step 08: Create Embeddings for each of the Text Chunk**

# %%
docsearch=Pinecone.from_texts([t.page_content for t in docs], embeddings, index_name=index_name)

# %% [markdown]
# #**Step 09: Similarity Search**

# %%
query = "how many students must we have in each team"

# %%
docs = docsearch.similarity_search(query, k=4)

# %%
docs
# Out:
# [Document(page_content='•Any request for a 3 member team must be approved by your professor beforehand.\n1'),
#  Document(page_content='•Any request for a 3 member team must be approved by your professor beforehand.\n1'),
#  Document(page_content='•Any request for a 3 member team must be approved by your professor beforehand.\n1'),
#  Document(page_content='•Any request for a 3 member team must be approved by your professor beforehand.\n1')]

# %% [markdown]
# #**Step 10: Calling the API**

# %%
# !pip install llama-cpp-python

# %%
from llama_cpp import Llama
# load the model from 2 pytorch_model-00001-of-00002.bin files pytorch_model-00002-of-00002.bin
LLM = Llama("ggml-model-q4_k.gguf")

# prompt = "Q: What is the capital of France? A:"

# output = LLM(prompt)
# output
# Out:
# AVX = 1 | AVX2 = 1 | AVX512 = 1 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 0 | SSE3 = 1 | SSSE3 = 0 | VSX = 0 |

# %%
SYSTEM_PROMPT = """Use the following pieces of context to answer the question at the end. and if the contenxt is relevant to the question, please answer the question while incorporating the context into your answer. """

B_INST, E_INST = "[INST]", "[/INST]"
B_SYS, E_SYS = "<>\n", "\n<>\n\n"

SYSTEM_PROMPT = B_SYS + SYSTEM_PROMPT + E_SYS

instruction = """
{context}

Question: {question}
Answer: 
"""

template = SYSTEM_PROMPT + instruction

template
# Out:
# '<>\nUse the following pieces of context to answer the question at the end. and if the contenxt is relevant to the question, please answer the question while incorporating the context into your answer. \n<>\n\n\n{context}\n\nQuestion: {question}\nAnswer: \n'

# %%
# # create a loop to ask questions and use the docsearch to et context
# question = "how does recomender system work?"
# # append the 4 context paragraphs
# context = docsearch.similarity_search(question, k=2)
# for c in context:
#     print(c.page_content)
#     print("--------------")
# # context = "-".join([c.page_content for c in context])
# # concatenate the context elements in one string
# context = " \n ".join([c.page_content for c in context])
# context = context.replace("\n", " ")
# prompt_template = PromptTemplate(template=template, input_variables=["context", "question"])
# prompt = prompt_template.format(context=context, question=question)
# print("Prompt:", prompt)
# output = LLM(prompt, max_tokens=500, 
#     stop=["Q:"],
#     echo=True)

# %%
# output

# %%
# output["usage"]

# %%
# print only the completion tokens and not the prompt
# print("Answer : " + output["choices"][0]["text"][len(prompt):])

# %%
import discord
import regex as re
import asyncio
import nest_asyncio
nest_asyncio.apply()
DISCORD_TOKEN = "MTE3NDMzNTgyNzIxNjcxNTg1OA.GkiifU.PRObWCZ5Ibh1eYR2scBBVdBCogDweJ5gcLu-dQ"


class MyClient(discord.Client):
    async def on_ready(self):
        print('Logged in as ' + str(self.user.name))
        print('The chatbot Id :: ' + str(self.user.id))

    async def on_message(self, message):
        if message.author == self.user:  # Check if the message is from the bot itself
            return
        print(message.content)
        # if message contains ? then it is a question
        if "?" in message.content:
            question = message.content
            # append the 4 context paragraphs
            context = docsearch.similarity_search(question, k=4)
            for c in context:
                print(c.page_content)
                print("--------------")
            # context = "-".join([c.page_content for c in context])
            # concatenate the context elements in one string
            context = " \n ".join([c.page_content for c in context])
            context = context.replace("\n", " ")
            prompt_template = PromptTemplate(template=template, input_variables=["context", "question"])
            prompt = prompt_template.format(context=context, question=question)
            print("Prompt:", prompt)
            output = LLM(prompt, max_tokens=500,
                         stop=["Q:"],
                         echo=True)
            # print only the completion tokens and not the prompt
            print("Answer : " + output["choices"][0]["text"][len(prompt):])
            await message.channel.send(output["choices"][0]["text"][len(prompt):])


async def main():
    intents = discord.Intents.default()
    intents.message_content = True  # Enable message content intent

    client = MyClient(intents=intents)
    await client.start(DISCORD_TOKEN)


if __name__ == '__main__':
    asyncio.get_event_loop().run_until_complete(main())


intents = discord.Intents.default()
intents.message_content = True  # Enable message content intent

client = MyClient(intents=intents)
client.run(DISCORD_TOKEN)
# Out:
# Logged in as chatbot
# The chatbot Id :: 1174335827216715858
# Quels sont les freins qui existent aujourd'hui pour faire de l'hydrogène, l'énergie du futur pour les transports ?
# Course outline
# I.Introduction
# II.States of matter
# III.Scales of study
# IV.Thermodynamic system
# V.Ideal and Van Der  Waals gases
# VI.Thermoelastic  coefficients
# --------------
# Course outline
# I.Introduction
# II.States of matter
# III.Scales of study
# IV.Thermodynamic system
# V.Ideal and Van Der  Waals gases
# VI.Thermoelastic  coefficients
# --------------
# Course outline
# I.Introduction
# II.States of matter
# III.Scales of study
# IV.Thermodynamic system
# V.Ideal and Van Der  Waals gases
# VI.Thermoelastic  coefficients
# --------------
# Course outline
# I.Introduction
# II.States of matter
# III.Scales of study
# IV.Thermodynamic system
# V.Ideal and Van Der  Waals gases
# VI.Thermoelastic  coefficients
# --------------
# Prompt: <>
# Use the following pieces of context to answer the question at the end. and if the contenxt is relevant to the question, please answer the question while incorporating the context into your answer.
# <>
#
#
# Course outline   I.Introduction   II.States of matter   III.Scales of study   IV.Thermodynamic system   V.Ideal and Van Der  Waals gases   VI.Thermoelastic  coefficients   Course outline   I.Introduction   II.States of matter   III.Scales of study   IV.Thermodynamic system   V.Ideal and Van Der  Waals gases   VI.Thermoelastic  coefficients   Course outline   I.Introduction   II.States of matter   III.Scales of study   IV.Thermodynamic system   V.Ideal and Van Der  Waals gases   VI.Thermoelastic  coefficients   Course outline   I.Introduction   II.States of matter   III.Scales of study   IV.Thermodynamic system   V.Ideal and Van Der  Waals gases   VI.Thermoelastic  coefficients
#
# Question: Quels sont les freins qui existent aujourd'hui pour faire de l'hydrogène, l'énergie du futur pour les transports ?
# Answer:
#
# Answer :
# L'un des obstacles majeurs à la production d'hydrogène est qu'elle nécessite une grande quantité d'énergie. L'eau doit être séparée en son oxygène et son hydrogène, ce qui nécessite l'utilisation de sources d'énergie telles que le charbon, le pétrole ou le gaz naturel pour produire de l'hydrogène à partir de l'eau. Cependant, la production d'hydrogène est en constante augmentation depuis plusieurs décennies et il y a des recherches en cours pour trouver des moyens plus efficaces et plus durables de produire de l'hydrogène.
#
# Un autre obstacle majeur à la production d'hydrogène est le coût élevé associé à cette production. Les technologies de production d'hydrogène disponibles actuellement sont encore très coûteuses
# Logged in as chatbot
# The chatbot Id :: 1174335827216715858
# Logged in as chatbot
# The chatbot Id :: 1174335827216715858
